# %%
from __future__ import division
from datetime import datetime 
import requests
from lxml import html, etree
import json
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from dateutil.relativedelta import relativedelta
from time import sleep
import requests
import json

import warnings
warnings.filterwarnings('ignore')

pd.options.display.max_columns = 100
pd.options.display.max_rows = 35
pd.options.display.width = 120

# %%
api_key = "AIzaSyCacsokTNbHu3X9o-wFcp-RSEtK-kpTsBw"
channelId = "UCTl3QQTvqHFjurroKxexy2Q"

# %%
parameters = {"part": "snippet",
              "maxResults": 5,
              "order": "date",
              "pageToken": "",
              "publishedAfter": "2006-12-31T23:59:59Z",
              #"publishedBefore": "2008-11-04T00:00:00Z",
              "q": "",
              "key": api_key,
              "type": "video",
              "channelId": channelId
              }
url = "https://www.googleapis.com/youtube/v3/search"

# %%
parameters["channelId"] = channelId
page = requests.request(method="get", url=url, params=parameters)
j_results = json.loads(page.text)
print (page.text)
# Out:
# {
#  "kind": "youtube#searchListResponse",
#  "etag": "\"RmznBCICv9YtgWaaa_nWDIH1_GM/kDmBpopPdugdMiADoc0ot4rdY5g\"",
#  "nextPageToken": "CAUQAA",
#  "regionCode": "US",
#  "pageInfo": {
#   "totalResults": 7714,
#   "resultsPerPage": 5
#  },
#  "items": [
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"RmznBCICv9YtgWaaa_nWDIH1_GM/djswRJAFqNo3X038WR4TE6gzGyI\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "tzmSVTSb2UE"
#    },
#    "snippet": {
#     "publishedAt": "2018-03-18T12:00:03.000Z",
#     "channelId": "UCTl3QQTvqHFjurroKxexy2Q",
#     "title": "The Legend of the Crazy Canucks Olympic Alpine Skiing Team | On the Line",
#     "description": "The story of how a group of Canadian daredevils Olympic skiers broke the European stranglehold on downhill skiing and became the talk of the alpine circuit at and around the Innsbruck 1976...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/tzmSVTSb2UE/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/tzmSVTSb2UE/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/tzmSVTSb2UE/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Olympic",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"RmznBCICv9YtgWaaa_nWDIH1_GM/6UJmjDdSNzN70oN5wbMziBtimQQ\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "-_JUKNfYNpc"
#    },
#    "snippet": {
#     "publishedAt": "2018-03-17T22:00:00.000Z",
#     "channelId": "UCTl3QQTvqHFjurroKxexy2Q",
#     "title": "Redmond's Olympic Heartache brings Fame & Praise | Strangest Moments",
#     "description": "Sometimes tragedy on the biggest stage can be more memorable than glory, as Great Britain 400m runner Derek Redmond can confirm from the Olympic Summer Games 1992 in Barcelona. Discover more...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/-_JUKNfYNpc/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/-_JUKNfYNpc/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/-_JUKNfYNpc/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Olympic",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"RmznBCICv9YtgWaaa_nWDIH1_GM/5vqM7WJzvyXbZ5FUjzB_l0Lrcgs\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "_VEeJ_t1Iyo"
#    },
#    "snippet": {
#     "publishedAt": "2018-03-17T12:00:03.000Z",
#     "channelId": "UCTl3QQTvqHFjurroKxexy2Q",
#     "title": "How Carolina Marin Defeated Asia’s Badminton Hegemony | Game Breakers",
#     "description": "When Spanish badminton star Carolina Marin's won Olympic gold beating Asian badminton dominance, many were surprised. Discover the story that got her to the top with the help of her coach Fernando...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/_VEeJ_t1Iyo/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/_VEeJ_t1Iyo/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/_VEeJ_t1Iyo/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Olympic",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"RmznBCICv9YtgWaaa_nWDIH1_GM/U9HZs5FPQPGBAIAmBxcjlir_guQ\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "LLgyrpQgE0Y"
#    },
#    "snippet": {
#     "publishedAt": "2018-03-16T22:00:01.000Z",
#     "channelId": "UCTl3QQTvqHFjurroKxexy2Q",
#     "title": "Deng Wei - The Weightlifter Going from Youth Olympic to Olympic Gold | Youth Olympic Games",
#     "description": "Deng Wei lifted 242kg on her debut at the Youth Olympic Games 2010 in Singapore and won gold in the Women's 58kg. At the Summer Games in Rio 2016, she opened with a 115kg snatch and set a new...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/LLgyrpQgE0Y/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/LLgyrpQgE0Y/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/LLgyrpQgE0Y/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Olympic",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"RmznBCICv9YtgWaaa_nWDIH1_GM/FYGBrNEzlYAjfoV_CSlyzybp7IQ\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "_5kHBSVplwo"
#    },
#    "snippet": {
#     "publishedAt": "2018-03-15T22:00:04.000Z",
#     "channelId": "UCTl3QQTvqHFjurroKxexy2Q",
#     "title": "Snow queen Marit Bjoergen enters the record books | Winter Olympics 2018 | PyeongChang 2018",
#     "description": "Norwegian cross-country skier Marit Bjoergen becomes the most decorated Winter Olympian in history with a total of 15 Olympic Medals. See every Cross-Country Skiing performance from PyeongChang...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/_5kHBSVplwo/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/_5kHBSVplwo/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/_5kHBSVplwo/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Olympic",
#     "liveBroadcastContent": "none"
#    }
#   }
#  ]
# }

# %%
parameters = {"part": "statistics",
              "id": "_5kHBSVplwo",
              "key": api_key,
              }
url = "https://www.googleapis.com/youtube/v3/videos"

# %%
page = requests.request(method="get", url=url, params=parameters)
j_results = json.loads(page.text)
print (page.text)
# Out:
# {
#  "kind": "youtube#videoListResponse",
#  "etag": "\"RmznBCICv9YtgWaaa_nWDIH1_GM/9q_0Su8mlpI7IaBZ2_3y7mq9mi0\"",
#  "pageInfo": {
#   "totalResults": 1,
#   "resultsPerPage": 1
#  },
#  "items": [
#   {
#    "kind": "youtube#video",
#    "etag": "\"RmznBCICv9YtgWaaa_nWDIH1_GM/JuuOotPF5cc6ZZGx3eKzjYdjIsc\"",
#    "id": "_5kHBSVplwo",
#    "statistics": {
#     "viewCount": "6027",
#     "likeCount": "134",
#     "dislikeCount": "8",
#     "favoriteCount": "0",
#     "commentCount": "16"
#    }
#   }
#  ]
# }

# %%
def _search_list(channelId="", publishedAfter=None, publishedBefore=None, pageToken=""):
    parameters = {"part": "id",
                  "maxResults": 50,
                  "order": "viewCount",
                  "pageToken": pageToken,
                  "channelId": channelId,
                  "type": "video",
                  "key": api_key,
                  }
    url = "https://www.googleapis.com/youtube/v3/search"
    
    if publishedAfter: parameters["publishedAfter"] = publishedAfter
    if publishedBefore: parameters["publishedBefore"] = publishedBefore
    
    page = requests.request(method="get", url=url, params=parameters)
    return json.loads(page.text)

def search_list(channelId="", publishedAfter=None, publishedBefore=None, max_requests=10):
    more_results = True
    pageToken=""
    results = []
    
    for counter in range(max_requests):
        j_results = _search_list(channelId=channelId, publishedAfter=publishedAfter, publishedBefore=publishedBefore, pageToken=pageToken)
        items = j_results.get("items", None)
        if items:
            results += [item["id"]["videoId"] for item in j_results["items"]]
            if "nextPageToken" in j_results:
                pageToken = j_results["nextPageToken"]
            else:
                return results
        else:
            return results
    return results

def _video_list(video_id_list):
    parameters = {"part": "statistics",
                  "id": ",".join(video_id_list),
                  "key": api_key,
                  "maxResults": 50
                  }
    url = "https://www.googleapis.com/youtube/v3/videos"
    page = requests.request(method="get", url=url, params=parameters)
    j_results = json.loads(page.text)
    df = pd.DataFrame([item["statistics"] for item in j_results["items"]], dtype=np.int64)
    df["video_id"] = [item["id"] for item in j_results["items"]]
    
    parameters["part"] = "snippet"
    page = requests.request(method="get", url=url, params=parameters)
    j_results = json.loads(page.text)
    df["publishedAt"] = [item["snippet"]["publishedAt"] for item in j_results["items"]]
    df["publishedAt"] = df["publishedAt"].apply(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.000Z"))
    df["date"] = df["publishedAt"].apply(lambda x: x.date())
    df["week"] = df["date"].apply(lambda x: x.isocalendar()[1])
    df["year"] = df["date"].apply(lambda x: str(x.year) + ' - ' + str(x.isocalendar()[1]))
    df["channelId"] = [item["snippet"]["channelId"] for item in j_results["items"]]
    df["title"] = [item["snippet"]["title"] for item in j_results["items"]]
    df["description"] = [item["snippet"]["description"] for item in j_results["items"]]
    df["channelTitle"] = [item["snippet"]["channelTitle"] for item in j_results["items"]]
    df["categoryId"] = [item["snippet"]["categoryId"] for item in j_results["items"]]
    return df

def video_list(video_id_list):
    values = []
    for index, item in enumerate(video_id_list[::50]):
        t_index = index * 50
        values.append(_video_list(video_id_list[t_index:t_index+50]))
    return pd.concat(values)

# %%
def get_data(olympicgames, publishedAfter):
    results_list = []
    for channelId in olympicgames:
        results = search_list(channelId=channelId,
                              publishedAfter=publishedAfter,
                              max_requests=50)

        stat_data_set = video_list(results)
        stat_data_set["olympics_season"] = channelId
        results_list.append(stat_data_set)
    data_set = pd.concat(results_list)
    return data_set

def get_all_data(olympicgames):
    return get_data(olympicgames, publishedAfter="2005-12-31T23:59:59Z")

# %%
olympicgames = ["UCTl3QQTvqHFjurroKxexy2Q"]
dataset = get_all_data(olympicgames)

# %%
list(dataset)
# Out:
# ['commentCount',
#  'dislikeCount',
#  'favoriteCount',
#  'likeCount',
#  'viewCount',
#  'video_id',
#  'publishedAt',
#  'date',
#  'week',
#  'year',
#  'channelId',
#  'title',
#  'description',
#  'channelTitle',
#  'categoryId',
#  'olympics_season']

# %%
dataset["video_id"].count()
# Out:
# 416

# %%
dataset.head()
# Out:
#    commentCount dislikeCount  favoriteCount likeCount  viewCount     video_id         publishedAt        date  week  \
# 0          6453         3167              0     59624   23441278  2O7K-8G2nwU 2012-08-05 22:01:13  2012-08-05    31
# 1          8973         4029              0    206548   22431112  CwzjlmBLfrQ 2012-07-27 21:39:25  2012-07-27    30
# 2          7234         3580              0     87125   17310928  1AS-dCdYZbo 2012-07-27 21:27:42  2012-07-27    30
# 3          5583         2787              0     42918   16766346  f6a3B499nwY 2012-08-03 06:15:03  2012-08-03    31
# 4          4746         1688              0     62969   16355886  PArTdhNda7k 2012-08-12 22:26:17  2012-08-12    32
#
#         year                 channelId                                              title  \
# 0  2012 - 31  UCTl3QQTvqHFjurroKxexy2Q  Usain Bolt Wins Olympic 100m Gold | London 201...
# 1  2012 - 30  UCTl3QQTvqHFjurroKxexy2Q  Mr. Bean Live Performance at the London 2012 O...
# 2  2012 - 30  UCTl3QQTvqHFjurroKxexy2Q   James Bond and The Queen London 2012 Performance
# 3  2012 - 31  UCTl3QQTvqHFjurroKxexy2Q  USA v Nigeria - USA Break Olympic Points Recor...
# 4  2012 - 32  UCTl3QQTvqHFjurroKxexy2Q  Spice Girls Reunion at London 2012 | Music Monday
#
#                                          description channelTitle categoryId           olympics_season
# 0  &id=2O7K-8G2nwU\n\nJamaican Usain Bolt sets a ...      Olympic         17  UCTl3QQTvqHFjurroKxexy2Q
# 1  Rowan Atkinson performs under the guise of his...      Olympic         17  UCTl3QQTvqHFjurroKxexy2Q
# 2  Daniel Craig reprises his role as British secr...      Olympic         17  UCTl3QQTvqHFjurroKxexy2Q
# 3  &id=f6a3B499nwY\n\nFull highlights from USA's ...      Olympic         17  UCTl3QQTvqHFjurroKxexy2Q
# 4  The Spice Girls perform a selection of their g...      Olympic         17  UCTl3QQTvqHFjurroKxexy2Q

# %%
new_year = dataset.join(dataset["year"].str.split(' - ', 1, expand = True).rename(columns={0:'importantyear', 1:'unimportant'}))
new_year
list(new_year)
# Out:
# ['commentCount',
#  'dislikeCount',
#  'favoriteCount',
#  'likeCount',
#  'viewCount',
#  'video_id',
#  'publishedAt',
#  'date',
#  'week',
#  'year',
#  'channelId',
#  'title',
#  'description',
#  'channelTitle',
#  'categoryId',
#  'olympics_season',
#  'importantyear',
#  'unimportant']

# %%
print(new_year["viewCount"].max())
print(new_year["viewCount"].min())
# Out:
# 23441278
# 1092

# %%
by_year = new_year.groupby(["importantyear"],)
total_views = (by_year["viewCount"].sum().reset_index())

total_views
# Out:
#   importantyear   viewCount
# 0          2010    71728755
# 1          2011    23577199
# 2          2012  1089329745
# 3          2013   102644200
# 4          2014   391980029
# 5          2015   456799390
# 6          2016   836026799
# 7          2017   595628520
# 8          2018   856671988

# %%
total_videos = (by_year["video_id"].count().reset_index())
total_videos
# Out:
#   importantyear  video_id
# 0          2010        66
# 1          2011        24
# 2          2012       831
# 3          2013        98
# 4          2014       301
# 5          2015       344
# 6          2016       640
# 7          2017       490
# 8          2018       678

# %%
current_palette= sns.color_palette(["#e74c3c", "#95a5a6", "#34495e", "#95a5a6"], 4)
sns.set_style("darkgrid")
plt.figure(1, figsize=(20, 10))
sns.barplot(total_views['importantyear'], total_views['viewCount'], palette=current_palette)
plt.savefig('YoutubeOlympicChannelViews.png')
#set title and labels
plt.title("View Count of Videos on Olympic YouTube Channel by Year", size = 24)
plt.xticks(size=14, rotation='vertical')
plt.xlabel(s = "Year", size=18)
plt.yticks(size=12)
plt.ylabel(s = "View Count", size=18)
plt.ylim(0,)

# adds notes at bottom
plt.annotate('Date of search: ' + datetime.now().strftime("%Y-%m-%d"), (0,0), (0, -80),\
             xycoords='axes fraction', textcoords='offset points', va='top', size=14)
plt.annotate("Colored bar = Olympic yr\nGrey bar=otherwise",  xy=(1000,3),\
            xycoords='figure points', size=14)

plt.axvspan(20, 20, color='y', alpha=0.2)
plt.savefig('YoutubeOlympicChannelViews.png')
plt.show()

#largest number is ~1.1 billion

# %%
current_palette= sns.color_palette(["#e74c3c", "#95a5a6", "#34495e", "#95a5a6"], 4)
sns.set_style("darkgrid")
plt.figure(1, figsize=(20, 10))
sns.barplot(total_videos['importantyear'], total_videos['video_id'], palette=current_palette)
plt.savefig('YoutubeOlympicChannelVidsPosted.png')
#set title and labels
plt.title("Total Videos Posted on Olympic YouTube Channel by Year", size = 24)
plt.xticks(size=14, rotation='vertical')
plt.xlabel(s = "Year", size=18)
plt.yticks(size=12)
plt.ylabel(s = "Number Videos Posted", size=18)
plt.ylim(0,)

# adds notes at bottom
plt.annotate('Date of search: ' + datetime.now().strftime("%Y-%m-%d"), (0,0), (0, -80),\
             xycoords='axes fraction', textcoords='offset points', va='top', size=14)
plt.annotate("Colored bar = Olympic yr\nGrey bar=otherwise",  xy=(1000,3),\
            xycoords='figure points', size=14)

plt.axvspan(20, 20, color='y', alpha=0.2)
plt.savefig('YoutubeOlympicChannelVidsPosted.png')
plt.show()

# %%
current_palette= sns.color_palette(["#e74c3c", "#95a5a6", "#34495e", "#95a5a6"], 4)
sns.set_style("darkgrid")
plt.figure(1, figsize=(20, 10))
sns.barplot(total_views['importantyear'], total_views['viewCount'], palette=current_palette)
plt.savefig('YoutubeOlympicChannelViews.png')
#set title and labels
plt.title("View Count of Videos on Olympic YouTube Channel by Year", size = 24)
plt.xticks(size=14, rotation='vertical')
plt.xlabel(s = "Year", size=18)
plt.yticks(size=12)
plt.ylabel(s = "View Count", size=18)
plt.ylim(0,)

# adds notes at bottom
plt.annotate('Date of search: ' + datetime.now().strftime("%Y-%m-%d"), (0,0), (0, -80),\
             xycoords='axes fraction', textcoords='offset points', va='top', size=14)
plt.annotate("Colored bar = Olympic yr\nGrey bar=otherwise",  xy=(1000,3),\
            xycoords='figure points', size=14)

plt.axvspan(20, 20, color='y', alpha=0.2)
plt.savefig('YoutubeOlympicChannelViews.png')
plt.show()

# %%
total_views.to_csv("olympicchannel_viewcount.csv")

# %%
total_videos.to_csv("ollympicchannel_vids.csv")
